# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_excel('1Vlna.xlsx')
df2 = pd.read_excel('2Vlna.xlsx')
df3 = pd.read_excel('3Vlna.xlsx')
df4 = pd.read_excel('4Vlna.xlsx')

df1['vlna'] = 1
df2['vlna'] = 2
df3['vlna'] = 3
df4['vlna'] = 4

df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
antivirotika = [
    'MD652 | FABIFLU TABLETS',
    'MD656 IV-BECT 6MG (ivermectin)',
    '5042D | VEKLURY',
    '9547D | PAXLOVID',
    'LAGEVRIO'
]

percenta_vlny = (
    df.groupby('vlna')[antivirotika]
    .mean() * 100
).reset_index()

df_plot = percenta_vlny.melt(
    id_vars='vlna',
    var_name='Liek',
    value_name='Percento'
)

plt.figure(figsize=(10,6))
ax = sns.barplot(
    x='Liek',
    y='Percento',
    hue='vlna',
    data=df_plot,
    palette='Set2'
)

plt.title('Percentuálne použitie antivirotík podľa vĺn')
plt.ylabel('Percento pacientov [%]')
plt.xlabel('Liek')
plt.ylim(0, 50)
plt.xticks(rotation=45)
plt.legend(title='Vlna')

for container in ax.containers:
    ax.bar_label(container, fmt="%.1f%%", label_type="edge", padding=2, fontsize=9)

plt.tight_layout()
plt.show()

# %%
vitaminy = [
    '00584 | PYRIDOXIN LÉČIVA INJ',
    '24836 | ACIDUM ASCORBICUM BBP',
    '24814 | CALCIFEROL BBP 7,5 MG/ML',
    '00498 | MAGNESIUM SULFURICUM BBP 100 MG/ML INJEKČNÝ ROZTOK',
    '00449 | EREVIT 300 MG/ML',
    '89145 | VITAMIN C-INJEKTOPAS',
    '92973 ALPHA D3'
]


percenta_vlny = (
    df.groupby('vlna')[vitaminy]
    .mean() * 100
).reset_index()

df_plot = percenta_vlny.melt(
    id_vars='vlna',
    var_name='Liek',
    value_name='Percento'
)


plt.figure(figsize=(16,10))
ax = sns.barplot(
    x='Liek',
    y='Percento',
    hue='vlna',
    data=df_plot,
    palette='Set2'
)


plt.title('Percentuálne použitie vitamínov podľa vĺn')
plt.ylabel('Percento pacientov [%]')
plt.xlabel('Liek')
plt.ylim(0, 105)
plt.xticks(rotation=45)
plt.legend(title='Vlna')


for container in ax.containers:
    ax.bar_label(container, fmt="%.1f%%", label_type="edge", padding=2, fontsize=9)

plt.tight_layout()
plt.show()

# %%
imuno = [
    '02963 | PREDNISON 20 LÉČIVA',
    '00269 | PREDNISON 5 LÉČIVA',
    '84090 | DEXAMED 6',
    '1275C | DEXAMETAZÓN KRKA',
    'MD661 BIODEXONE-DEXAMETHASONE',
    '2410B HYDROCORTISONE',
    '3242C | OLUMIANT 4 MG',
    'Anakinra',
    'RoActemra'
]

percenta_vlny = (
    df.groupby('vlna')[imuno]
    .mean() * 100
).reset_index()

df_plot = percenta_vlny.melt(
    id_vars='vlna',
    var_name='Liek',
    value_name='Percento'
)

plt.figure(figsize=(16,8))
ax = sns.barplot(
    x='Liek',
    y='Percento',
    hue='vlna',
    data=df_plot,
    palette='Set2'  # môžeš zmeniť farebnú paletu
)

plt.title('Percentuálne použitie imuno liekov podľa vĺn')
plt.ylabel('Percento pacientov [%]')
plt.xlabel('Liek')
plt.ylim(0, 100)
plt.xticks(rotation=45)
plt.legend(title='Vlna')

for container in ax.containers:
    ax.bar_label(container, fmt="%.1f%%", label_type="edge", padding=2, fontsize=9)

plt.tight_layout()
plt.show()

# %%
imuno_plus = [
    '34045 | POLYOXIDONIUM 6 MG',
    '87299 | IMUNOR',
    '56930 IMMODIN',
    'Isoprinosine, ',
    '3879d INOMED'
]

percenta_vlny = (
    df.groupby('vlna')[imuno_plus]
    .mean() * 100
).reset_index()

df_plot = percenta_vlny.melt(
    id_vars='vlna',
    var_name='Liek',
    value_name='Percento'
)

plt.figure(figsize=(12,8))
ax = sns.barplot(
    x='Liek',
    y='Percento',
    hue='vlna',
    data=df_plot,
    palette='Set2'
)

plt.title('Percentuálne použitie imuno+ liekov podľa vĺn')
plt.ylabel('Percento pacientov [%]')
plt.xlabel('Liek')
plt.ylim(0, 105)
plt.xticks(rotation=45)
plt.legend(title='Vlna')

for container in ax.containers:
    ax.bar_label(container, fmt="%.1f%%", label_type="edge", padding=2, fontsize=9)

plt.tight_layout()
plt.show()

# %%
antibiotika = [
    '35715 Azithromycin',
    '45954 Ceftriaxon',
    '0471B MOLOXIN',
    '9819A MOXIFLOXACIN',
    '58730 CIPROFLOXACIN KABI 200',
    '58746 CIPROFLOXACINKABI 400'
]

percenta_vlny = (
    df.groupby('vlna')[antibiotika]
    .mean() * 100
).reset_index()

df_plot = percenta_vlny.melt(
    id_vars='vlna',
    var_name='Liek',
    value_name='Percento'
)

plt.figure(figsize=(16,9))
ax = sns.barplot(
    x='Liek',
    y='Percento',
    hue='vlna',
    data=df_plot,
    palette='Set2' 
)

plt.title('Percentuálne použitie antibiotík podľa vĺn')
plt.ylabel('Percento pacientov [%]')
plt.xlabel('Liek')
plt.ylim(0, 105)
plt.xticks(rotation=45)
plt.legend(title='Vlna')

for container in ax.containers:
    ax.bar_label(container, fmt="%.1f%%", label_type="edge", padding=2, fontsize=9)

plt.tight_layout()
plt.show()

# %%
ine_ppi = [
    '05044 OZZION',
    '4147C OMEMYL',
    '89662 NOLPAZA',
    '39397 PANTOPRAZOL',
    '62916 SMECTA',
    '30639 REASEC',
    '84370 LAGOSA',
    '93105 DEGAN '
]

percenta_vlny = (
    df.groupby('vlna')[ine_ppi]
    .mean() * 100
).reset_index()


df_plot = percenta_vlny.melt(
    id_vars='vlna',
    var_name='Liek',
    value_name='Percento'
)

plt.figure(figsize=(16,10))
ax = sns.barplot(
    x='Liek',
    y='Percento',
    hue='vlna',
    data=df_plot,
    palette='Set2' 
)

plt.title('Percentuálne použitie iných/PPI podľa vĺn')
plt.ylabel('Percento pacientov [%]')
plt.xlabel('Liek')
plt.ylim(0, 65)
plt.xticks(rotation=45)
plt.legend(title='Vlna')

for container in ax.containers:
    ax.bar_label(container, fmt="%.1f%%", label_type="edge", padding=2, fontsize=9)

plt.tight_layout()
plt.show()

# %%
kasel = [
    '94918 AMBROBENE',
    '24859 PENTOXYPHILLINUM',
    '8893 ACC INJEKT',
    '24949 CODEIN ',
    '26846 OXANTIL'
]

percenta_vlny = (
    df.groupby('vlna')[kasel]
    .mean() * 100
).reset_index()

df_plot = percenta_vlny.melt(
    id_vars='vlna',
    var_name='Liek',
    value_name='Percento'
)

plt.figure(figsize=(14,8))
ax = sns.barplot(
    x='Liek',
    y='Percento',
    hue='vlna',
    data=df_plot,
    palette='Set2'
)

plt.title('Percentuálne použitie liekov na kašeľ podľa vĺn')
plt.ylabel('Percento pacientov [%]')
plt.xlabel('Liek')
plt.ylim(0, 75)
plt.xticks(rotation=45)
plt.legend(title='Vlna')

for container in ax.containers:
    ax.bar_label(container, fmt="%.1f%%", label_type="edge", padding=2, fontsize=9)

plt.tight_layout()
plt.show()

# %%
antikoagulancia = [
    'FRAXIPARIN',
    'CLEXANE',
    'FRAGMIN',
    'ASPIRIN',
    'ANOPYRIN'
]

percenta_vlny = (
    df.groupby('vlna')[antikoagulancia]
    .mean() * 100
).reset_index()

df_plot = percenta_vlny.melt(
    id_vars='vlna',
    var_name='Liek',
    value_name='Percento'
)

plt.figure(figsize=(14,8))
ax = sns.barplot(
    x='Liek',
    y='Percento',
    hue='vlna',
    data=df_plot,
    palette='Set2'
)

plt.title('Percentuálne použitie antikoagulancií podľa vĺn')
plt.ylabel('Percento pacientov [%]')
plt.xlabel('Liek')
plt.ylim(0, 105)
plt.xticks(rotation=45)
plt.legend(title='Vlna')

for container in ax.containers:
    ax.bar_label(container, fmt="%.1f%%", label_type="edge", padding=2, fontsize=9)

plt.tight_layout()
plt.show()
